# %%
import pandas as pd

# %%
nov=pd.read_csv("JC-202011-citibike-tripdata.csv/JC-202011-citibike-tripdata.csv")
dec=pd.read_csv("JC-202012-citibike-tripdata.csv/JC-202012-citibike-tripdata.csv")
en=pd.read_csv("JC-202101-citibike-tripdata.csv/JC-202101-citibike-tripdata.csv")
feb=pd.read_csv("JC-202102-citibike-tripdata.csv/JC-202102-citibike-tripdata.csv")
mar=pd.read_csv("JC-202103-citibike-tripdata.csv/JC-202103-citibike-tripdata.csv")
apr=pd.read_csv("JC-202104-citibike-tripdata.csv/JC-202104-citibike-tripdata.csv")
# Out:
#       tripduration                 starttime                  stoptime  \
# 0              683  2021-02-01 00:08:57.2940  2021-02-01 00:20:21.2680
# 1             2850  2021-02-01 00:21:12.4910  2021-02-01 01:08:42.9560
# 2              545  2021-02-01 00:53:08.7500  2021-02-01 01:02:14.3890
# 3              473  2021-02-01 00:59:10.1110  2021-02-01 01:07:03.8480
# 4              748  2021-02-01 01:01:29.4990  2021-02-01 01:13:57.8940
# ...            ...                       ...                       ...
# 4720           355  2021-02-28 23:28:40.4160  2021-02-28 23:34:35.7310
# 4721           269  2021-02-28 23:30:50.3470  2021-02-28 23:35:20.2370
# 4722           193  2021-02-28 23:35:24.5920  2021-02-28 23:38:38.3930
# 4723          2550  2021-02-28 23:39:43.4490  2021-03-01 00:22:13.4840
# 4724           358  2021-02-28 23:41:20.4330  2021-02-28 23:47:18.8140
#
#       start station id start station name  start station latitude  \
# ...

# %%
bikes_TB=nov.append([dec,en,feb,mar,apr ])
bikes_TB
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               756  2020-11-01 00:11:32.6250  2020-11-01 00:24:09.5850
# 1               584  2020-11-01 00:14:20.4820  2020-11-01 00:24:04.7820
# 2               403  2020-11-01 00:22:55.8820  2020-11-01 00:29:39.0950
# 3               498  2020-11-01 00:41:37.4270  2020-11-01 00:49:55.7010
# 4               151  2020-11-01 00:53:21.2340  2020-11-01 00:55:52.8060
# ...             ...                       ...                       ...
# 23313          1700  2021-04-30 23:55:22.9900  2021-05-01 00:23:43.6660
# 23314          1958  2021-04-30 23:55:50.6830  2021-05-01 00:28:28.7000
# 23315           877  2021-04-30 23:57:33.1520  2021-05-01 00:12:11.0930
# 23316           173  2021-04-30 23:59:38.4630  2021-05-01 00:02:31.8160
# 23317           174  2021-04-30 23:59:43.2470  2021-05-01 00:02:37.5830
#
#        start station id start station name  start station latitude  \
# ...

# %%
bikes_TB.to_csv('bikes_tb.csv', index=False)
